# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import os 
from multiprocessing import Pool

# ========================== DIFUSIÓN VECTORIAL =============================

def difusion_skin(m, n, t, dt, nu, u_init, Gamma):
    u_prev = np.zeros([m, n])
    u_curr = np.zeros([m, n])
    Gamma = Gamma * nu * dt

    core_slice = (slice(1, m-1), slice(1, n-1))
    gamma_slice = (slice(1, m-1), slice(1, n-1), slice(None))

    neighbor_indices = [
        (slice(2, m), slice(1, n-1)),     # East
        (slice(2, m), slice(2, n)),       # NE
        (slice(1, m-1), slice(2, n)),     # N
        (slice(0, m-2), slice(2, n)),     # NW
        (slice(0, m-2), slice(1, n-1)),   # West
        (slice(0, m-2), slice(0, n-2)),   # SW
        (slice(1, m-1), slice(0, n-2)),   # S
        (slice(2, m), slice(0, n-2))      # SE
    ]

    boundary_indices = {
        'inlet': (slice(None), 0),
        'outlet': (slice(None), n-1),
        'outlet_ref': (slice(None), n-2),
        'left': (m-1, slice(None)),
        'left_ref': (m-2, slice(None)),
        'right': (0, slice(None)),
        'right_ref': (1, slice(None))
    }

    neighbor_arrays = np.zeros((m-2, n-2, 9))

    for k in range(1, t):
        neighbor_arrays[:, :, 0] = u_prev[core_slice]
        for i in range(8):
            neighbor_arrays[:, :, i+1] = u_prev[neighbor_indices[i]]

        u_curr[core_slice] = u_prev[core_slice] + np.einsum('ijk,ijk->ij', Gamma[gamma_slice], neighbor_arrays)

        u_curr[boundary_indices['inlet']] = u_init
        u_curr[boundary_indices['outlet']] = u_curr[boundary_indices['outlet_ref']]
        u_curr[boundary_indices['left']] = u_curr[boundary_indices['left_ref']]
        u_curr[boundary_indices['right']] = u_curr[boundary_indices['right_ref']]

        u_prev, u_curr = u_curr, u_prev

    return u_prev

# ========================== GAMMAS (COEFICIENTES GFD) ======================

def Gammas(x, y, L):
    m, n = x.shape
    Gamma = np.zeros([m, n, 9])

    i_range = slice(1, m-1)
    j_range = slice(1, n-1)
    x_center = x[i_range, j_range]
    y_center = y[i_range, j_range]

    dx_neighbors = np.stack([
        x[2:m, 1:n-1] - x_center,
        x[2:m, 2:n] - x_center,
        x[1:m-1, 2:n] - x_center,
        x[0:m-2, 2:n] - x_center,
        x[0:m-2, 1:n-1] - x_center,
        x[0:m-2, 0:n-2] - x_center,
        x[1:m-1, 0:n-2] - x_center,
        x[2:m, 0:n-2] - x_center
    ], axis=-1)

    dy_neighbors = np.stack([
        y[2:m, 1:n-1] - y_center,
        y[2:m, 2:n] - y_center,
        y[1:m-1, 2:n] - y_center,
        y[0:m-2, 2:n] - y_center,
        y[0:m-2, 1:n-1] - y_center,
        y[0:m-2, 0:n-2] - y_center,
        y[1:m-1, 0:n-2] - y_center,
        y[2:m, 0:n-2] - y_center
    ], axis=-1)

    M_matrices = np.stack([
        dx_neighbors,
        dy_neighbors,
        dx_neighbors**2,
        dx_neighbors * dy_neighbors,
        dy_neighbors**2
    ], axis=2)

    original_shape = M_matrices.shape[:2]
    M_reshaped = M_matrices.reshape(-1, 5, 8)

    M_pinv_list = [np.linalg.pinv(M_reshaped[k]) for k in range(M_reshaped.shape[0])]
    M_pinv = np.array(M_pinv_list).reshape(original_shape[0], original_shape[1], 8, 5)

    L_flat = L.flatten()
    YY = np.einsum('ijkl,l->ijk', M_pinv, L_flat)
    Gamma_0 = -np.sum(YY, axis=2)

    Gamma[1:m-1, 1:n-1, 0] = Gamma_0
    Gamma[1:m-1, 1:n-1, 1:9] = YY

    return Gamma

# ========================== MAIN ===========================================

# Cargar datos de la malla
datos = scipy.io.loadmat('piel224.mat')
x, y = datos["x"], datos["y"]
m, n = x.shape
output_dir = 'skin224'

# Operador Laplaciano
L = np.vstack([[0], [0], [2], [0], [2]])
Gamma = Gammas(x, y, L)

# ========================== FUNCION PARA PARALELIZAR =======================

def run_case(params):
    ss, j = params
    nu = ss * 1e-9
    u_init = j

    # Definir parámetros locales
    t_local = 500
    T_local = np.linspace(0, 20 * 3600, t_local)
    dt_local = T_local[1] - T_local[0]

    dx_min = np.min(np.sqrt((x[1:, :] - x[:-1, :])**2 + (y[1:, :] - y[:-1, :])**2))
    alpha = nu * dt_local / dx_min**2

    while alpha > 0.05:
        t_local = int(t_local * 1.1)
        T_local = np.linspace(0, 20 * 3600, t_local)
        dt_local = T_local[1] - T_local[0]
        alpha = nu * dt_local / dx_min**2

    print(f"Simulando para Ci={j}, nu={nu:.2e}...")

    u_ap = difusion_skin(m, n, t_local, dt_local, nu, u_init, Gamma)
    if u_ap is None:
        return

    carpeta_nu = os.path.join(output_dir, f"nu_{nu:.9f}")
    os.makedirs(carpeta_nu, exist_ok=True)

    plt.figure(figsize=(8, 6))
    plt.pcolormesh(x, y, u_ap, shading='auto', cmap='cool_r', vmin=0, vmax=900)
    plt.axis('off')

    filename = os.path.join(carpeta_nu, f"c_{j:03d}.png")
    plt.savefig(filename, dpi=75, bbox_inches='tight', pad_inches=0)
    plt.close()

    print(f"Guardado: {filename}")

# ========================== EJECUCIÓN ======================================

if __name__ == "__main__":
    combinations = [(i, j) for i in range(1, 201) for j in range(1, 901)]
    with Pool(processes=1) as pool:
        pool.map(run_case, combinations)
# Out:
# Simulando para Ci=1, nu=1.00e-09...
# /tmp/ipykernel_42741/756432562.py:155: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x, y, u_ap, shading='auto', cmap='cool_r', vmin=0, vmax=900)
# Guardado: skin224/nu_0.000000001/c_001.png
# Simulando para Ci=2, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_002.png
# Simulando para Ci=3, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_003.png
# Simulando para Ci=4, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_004.png
# Simulando para Ci=5, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_005.png
# Simulando para Ci=6, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_006.png
# Simulando para Ci=7, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_007.png
# Simulando para Ci=8, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_008.png
# Simulando para Ci=9, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_009.png
# Simulando para Ci=10, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_010.png
# Simulando para Ci=11, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_011.png
# Simulando para Ci=12, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_012.png
# Simulando para Ci=13, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_013.png
# Simulando para Ci=14, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_014.png
# Simulando para Ci=15, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_015.png
# Simulando para Ci=16, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_016.png
# Simulando para Ci=17, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_017.png
# Simulando para Ci=18, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_018.png
# Simulando para Ci=19, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_019.png
# Simulando para Ci=20, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_020.png
# Simulando para Ci=21, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_021.png
# Simulando para Ci=22, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_022.png
# Simulando para Ci=23, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_023.png
# Simulando para Ci=24, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_024.png
# Simulando para Ci=25, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_025.png
# Simulando para Ci=26, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_026.png
# Simulando para Ci=27, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_027.png
# Simulando para Ci=28, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_028.png
# Simulando para Ci=29, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_029.png
# Simulando para Ci=30, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_030.png
# Simulando para Ci=31, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_031.png
# Simulando para Ci=32, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_032.png
# Simulando para Ci=33, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_033.png
# Simulando para Ci=34, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_034.png
# Simulando para Ci=35, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_035.png
# Simulando para Ci=36, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_036.png
# Simulando para Ci=37, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_037.png
# Simulando para Ci=38, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_038.png
# Simulando para Ci=39, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_039.png
# Simulando para Ci=40, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_040.png
# Simulando para Ci=41, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_041.png
# Simulando para Ci=42, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_042.png
# Simulando para Ci=43, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_043.png
# Simulando para Ci=44, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_044.png
# Simulando para Ci=45, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_045.png
# Simulando para Ci=46, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_046.png
# Simulando para Ci=47, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_047.png
# Simulando para Ci=48, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_048.png
# Simulando para Ci=49, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_049.png
# Simulando para Ci=50, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_050.png
# Simulando para Ci=51, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_051.png
# Simulando para Ci=52, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_052.png
# Simulando para Ci=53, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_053.png
# Simulando para Ci=54, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_054.png
# Simulando para Ci=55, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_055.png
# Simulando para Ci=56, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_056.png
# Simulando para Ci=57, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_057.png
# Simulando para Ci=58, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_058.png
# Simulando para Ci=59, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_059.png
# Simulando para Ci=60, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_060.png
# Simulando para Ci=61, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_061.png
# Simulando para Ci=62, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_062.png
# Simulando para Ci=63, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_063.png
# Simulando para Ci=64, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_064.png
# Simulando para Ci=65, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_065.png
# Simulando para Ci=66, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_066.png
# Simulando para Ci=67, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_067.png
# Simulando para Ci=68, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_068.png
# Simulando para Ci=69, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_069.png
# Simulando para Ci=70, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_070.png
# Simulando para Ci=71, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_071.png
# Simulando para Ci=72, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_072.png
# Simulando para Ci=73, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_073.png
# Simulando para Ci=74, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_074.png
# Simulando para Ci=75, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_075.png
# Simulando para Ci=76, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_076.png
# Simulando para Ci=77, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_077.png
# Simulando para Ci=78, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_078.png
# Simulando para Ci=79, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_079.png
# Simulando para Ci=80, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_080.png
# Simulando para Ci=81, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_081.png
# Simulando para Ci=82, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_082.png
# Simulando para Ci=83, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_083.png
# Simulando para Ci=84, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_084.png
# Simulando para Ci=85, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_085.png
# Simulando para Ci=86, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_086.png
# Simulando para Ci=87, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_087.png
# Simulando para Ci=88, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_088.png
# Simulando para Ci=89, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_089.png
# Simulando para Ci=90, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_090.png
# Simulando para Ci=91, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_091.png
# Simulando para Ci=92, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_092.png
# Simulando para Ci=93, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_093.png
# Simulando para Ci=94, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_094.png
# Simulando para Ci=95, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_095.png
# Simulando para Ci=96, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_096.png
# Simulando para Ci=97, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_097.png
# Simulando para Ci=98, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_098.png
# Simulando para Ci=99, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_099.png
# Simulando para Ci=100, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_100.png
# Simulando para Ci=101, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_101.png
# Simulando para Ci=102, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_102.png
# Simulando para Ci=103, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_103.png
# Simulando para Ci=104, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_104.png
# Simulando para Ci=105, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_105.png
# Simulando para Ci=106, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_106.png
# Simulando para Ci=107, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_107.png
# Simulando para Ci=108, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_108.png
# Simulando para Ci=109, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_109.png
# Simulando para Ci=110, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_110.png
# Simulando para Ci=111, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_111.png
# Simulando para Ci=112, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_112.png
# Simulando para Ci=113, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_113.png
# Simulando para Ci=114, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_114.png
# Simulando para Ci=115, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_115.png
# Simulando para Ci=116, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_116.png
# Simulando para Ci=117, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_117.png
# Simulando para Ci=118, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_118.png
# Simulando para Ci=119, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_119.png
# Simulando para Ci=120, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_120.png
# Simulando para Ci=121, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_121.png
# Simulando para Ci=122, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_122.png
# Simulando para Ci=123, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_123.png
# Simulando para Ci=124, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_124.png
# Simulando para Ci=125, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_125.png
# Simulando para Ci=126, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_126.png
# Simulando para Ci=127, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_127.png
# Simulando para Ci=128, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_128.png
# Simulando para Ci=129, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_129.png
# Simulando para Ci=130, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_130.png
# Simulando para Ci=131, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_131.png
# Simulando para Ci=132, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_132.png
# Simulando para Ci=133, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_133.png
# Simulando para Ci=134, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_134.png
# Simulando para Ci=135, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_135.png
# Simulando para Ci=136, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_136.png
# Simulando para Ci=137, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_137.png
# Simulando para Ci=138, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_138.png
# Simulando para Ci=139, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_139.png
# Simulando para Ci=140, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_140.png
# Simulando para Ci=141, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_141.png
# Simulando para Ci=142, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_142.png
# Simulando para Ci=143, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_143.png
# Simulando para Ci=144, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_144.png
# Simulando para Ci=145, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_145.png
# Simulando para Ci=146, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_146.png
# Simulando para Ci=147, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_147.png
# Simulando para Ci=148, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_148.png
# Simulando para Ci=149, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_149.png
# Simulando para Ci=150, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_150.png
# Simulando para Ci=151, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_151.png
# Simulando para Ci=152, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_152.png
# Simulando para Ci=153, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_153.png
# Simulando para Ci=154, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_154.png
# Simulando para Ci=155, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_155.png
# Simulando para Ci=156, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_156.png
# Simulando para Ci=157, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_157.png
# Simulando para Ci=158, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_158.png
# Simulando para Ci=159, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_159.png
# Simulando para Ci=160, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_160.png
# Simulando para Ci=161, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_161.png
# Simulando para Ci=162, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_162.png
# Simulando para Ci=163, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_163.png
# Simulando para Ci=164, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_164.png
# Simulando para Ci=165, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_165.png
# Simulando para Ci=166, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_166.png
# Simulando para Ci=167, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_167.png
# Simulando para Ci=168, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_168.png
# Simulando para Ci=169, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_169.png
# Simulando para Ci=170, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_170.png
# Simulando para Ci=171, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_171.png
# Simulando para Ci=172, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_172.png
# Simulando para Ci=173, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_173.png
# Simulando para Ci=174, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_174.png
# Simulando para Ci=175, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_175.png
# Simulando para Ci=176, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_176.png
# Simulando para Ci=177, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_177.png
# Simulando para Ci=178, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_178.png
# Simulando para Ci=179, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_179.png
# Simulando para Ci=180, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_180.png
# Simulando para Ci=181, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_181.png
# Simulando para Ci=182, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_182.png
# Simulando para Ci=183, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_183.png
# Simulando para Ci=184, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_184.png
# Simulando para Ci=185, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_185.png
# Simulando para Ci=186, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_186.png
# Simulando para Ci=187, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_187.png
# Simulando para Ci=188, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_188.png
# Simulando para Ci=189, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_189.png
# Simulando para Ci=190, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_190.png
# Simulando para Ci=191, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_191.png
# Simulando para Ci=192, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_192.png
# Simulando para Ci=193, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_193.png
# Simulando para Ci=194, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_194.png
# Simulando para Ci=195, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_195.png
# Simulando para Ci=196, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_196.png
# Simulando para Ci=197, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_197.png
# Simulando para Ci=198, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_198.png
# Simulando para Ci=199, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_199.png
# Simulando para Ci=200, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_200.png
# Simulando para Ci=201, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_201.png
# Simulando para Ci=202, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_202.png
# Simulando para Ci=203, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_203.png
# Simulando para Ci=204, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_204.png
# Simulando para Ci=205, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_205.png
# Simulando para Ci=206, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_206.png
# Simulando para Ci=207, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_207.png
# Simulando para Ci=208, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_208.png
# Simulando para Ci=209, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_209.png
# Simulando para Ci=210, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_210.png
# Simulando para Ci=211, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_211.png
# Simulando para Ci=212, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_212.png
# Simulando para Ci=213, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_213.png
# Simulando para Ci=214, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_214.png
# Simulando para Ci=215, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_215.png
# Simulando para Ci=216, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_216.png
# Simulando para Ci=217, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_217.png
# Simulando para Ci=218, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_218.png
# Simulando para Ci=219, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_219.png
# Simulando para Ci=220, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_220.png
# Simulando para Ci=221, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_221.png
# Simulando para Ci=222, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_222.png
# Simulando para Ci=223, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_223.png
# Simulando para Ci=224, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_224.png
# Simulando para Ci=225, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_225.png
# Simulando para Ci=226, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_226.png
# Simulando para Ci=227, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_227.png
# Simulando para Ci=228, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_228.png
# Simulando para Ci=229, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_229.png
# Simulando para Ci=230, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_230.png
# Simulando para Ci=231, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_231.png
# Simulando para Ci=232, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_232.png
# Simulando para Ci=233, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_233.png
# Simulando para Ci=234, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_234.png
# Simulando para Ci=235, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_235.png
# Simulando para Ci=236, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_236.png
# Simulando para Ci=237, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_237.png
# Simulando para Ci=238, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_238.png
# Simulando para Ci=239, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_239.png
# Simulando para Ci=240, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_240.png
# Simulando para Ci=241, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_241.png
# Simulando para Ci=242, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_242.png
# Simulando para Ci=243, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_243.png
# Simulando para Ci=244, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_244.png
# Simulando para Ci=245, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_245.png
# Simulando para Ci=246, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_246.png
# Simulando para Ci=247, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_247.png
# Simulando para Ci=248, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_248.png
# Simulando para Ci=249, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_249.png
# Simulando para Ci=250, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_250.png
# Simulando para Ci=251, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_251.png
# Simulando para Ci=252, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_252.png
# Simulando para Ci=253, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_253.png
# Simulando para Ci=254, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_254.png
# Simulando para Ci=255, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_255.png
# Simulando para Ci=256, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_256.png
# Simulando para Ci=257, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_257.png
# Simulando para Ci=258, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_258.png
# Simulando para Ci=259, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_259.png
# Simulando para Ci=260, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_260.png
# Simulando para Ci=261, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_261.png
# Simulando para Ci=262, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_262.png
# Simulando para Ci=263, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_263.png
# Simulando para Ci=264, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_264.png
# Simulando para Ci=265, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_265.png
# Simulando para Ci=266, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_266.png
# Simulando para Ci=267, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_267.png
# Simulando para Ci=268, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_268.png
# Simulando para Ci=269, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_269.png
# Simulando para Ci=270, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_270.png
# Simulando para Ci=271, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_271.png
# Simulando para Ci=272, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_272.png
# Simulando para Ci=273, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_273.png
# Simulando para Ci=274, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_274.png
# Simulando para Ci=275, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_275.png
# Simulando para Ci=276, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_276.png
# Simulando para Ci=277, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_277.png
# Simulando para Ci=278, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_278.png
# Simulando para Ci=279, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_279.png
# Simulando para Ci=280, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_280.png
# Simulando para Ci=281, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_281.png
# Simulando para Ci=282, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_282.png
# Simulando para Ci=283, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_283.png
# Simulando para Ci=284, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_284.png
# Simulando para Ci=285, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_285.png
# Simulando para Ci=286, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_286.png
# Simulando para Ci=287, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_287.png
# Simulando para Ci=288, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_288.png
# Simulando para Ci=289, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_289.png
# Simulando para Ci=290, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_290.png
# Simulando para Ci=291, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_291.png
# Simulando para Ci=292, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_292.png
# Simulando para Ci=293, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_293.png
# Simulando para Ci=294, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_294.png
# Simulando para Ci=295, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_295.png
# Simulando para Ci=296, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_296.png
# Simulando para Ci=297, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_297.png
# Simulando para Ci=298, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_298.png
# Simulando para Ci=299, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_299.png
# Simulando para Ci=300, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_300.png
# Simulando para Ci=301, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_301.png
# Simulando para Ci=302, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_302.png
# Simulando para Ci=303, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_303.png
# Simulando para Ci=304, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_304.png
# Simulando para Ci=305, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_305.png
# Simulando para Ci=306, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_306.png
# Simulando para Ci=307, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_307.png
# Simulando para Ci=308, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_308.png
# Simulando para Ci=309, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_309.png
# Simulando para Ci=310, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_310.png
# Simulando para Ci=311, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_311.png
# Simulando para Ci=312, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_312.png
# Simulando para Ci=313, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_313.png
# Simulando para Ci=314, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_314.png
# Simulando para Ci=315, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_315.png
# Simulando para Ci=316, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_316.png
# Simulando para Ci=317, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_317.png
# Simulando para Ci=318, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_318.png
# Simulando para Ci=319, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_319.png
# Simulando para Ci=320, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_320.png
# Simulando para Ci=321, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_321.png
# Simulando para Ci=322, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_322.png
# Simulando para Ci=323, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_323.png
# Simulando para Ci=324, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_324.png
# Simulando para Ci=325, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_325.png
# Simulando para Ci=326, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_326.png
# Simulando para Ci=327, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_327.png
# Simulando para Ci=328, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_328.png
# Simulando para Ci=329, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_329.png
# Simulando para Ci=330, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_330.png
# Simulando para Ci=331, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_331.png
# Simulando para Ci=332, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_332.png
# Simulando para Ci=333, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_333.png
# Simulando para Ci=334, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_334.png
# Simulando para Ci=335, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_335.png
# Simulando para Ci=336, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_336.png
# Simulando para Ci=337, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_337.png
# Simulando para Ci=338, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_338.png
# Simulando para Ci=339, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_339.png
# Simulando para Ci=340, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_340.png
# Simulando para Ci=341, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_341.png
# Simulando para Ci=342, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_342.png
# Simulando para Ci=343, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_343.png
# Simulando para Ci=344, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_344.png
# Simulando para Ci=345, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_345.png
# Simulando para Ci=346, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_346.png
# Simulando para Ci=347, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_347.png
# Simulando para Ci=348, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_348.png
# Simulando para Ci=349, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_349.png
# Simulando para Ci=350, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_350.png
# Simulando para Ci=351, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_351.png
# Simulando para Ci=352, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_352.png
# Simulando para Ci=353, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_353.png
# Simulando para Ci=354, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_354.png
# Simulando para Ci=355, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_355.png
# Simulando para Ci=356, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_356.png
# Simulando para Ci=357, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_357.png
# Simulando para Ci=358, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_358.png
# Simulando para Ci=359, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_359.png
# Simulando para Ci=360, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_360.png
# Simulando para Ci=361, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_361.png
# Simulando para Ci=362, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_362.png
# Simulando para Ci=363, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_363.png
# Simulando para Ci=364, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_364.png
# Simulando para Ci=365, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_365.png
# Simulando para Ci=366, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_366.png
# Simulando para Ci=367, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_367.png
# Simulando para Ci=368, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_368.png
# Simulando para Ci=369, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_369.png
# Simulando para Ci=370, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_370.png
# Simulando para Ci=371, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_371.png
# Simulando para Ci=372, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_372.png
# Simulando para Ci=373, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_373.png
# Simulando para Ci=374, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_374.png
# Simulando para Ci=375, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_375.png
# Simulando para Ci=376, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_376.png
# Simulando para Ci=377, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_377.png
# Simulando para Ci=378, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_378.png
# Simulando para Ci=379, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_379.png
# Simulando para Ci=380, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_380.png
# Simulando para Ci=381, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_381.png
# Simulando para Ci=382, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_382.png
# Simulando para Ci=383, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_383.png
# Simulando para Ci=384, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_384.png
# Simulando para Ci=385, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_385.png
# Simulando para Ci=386, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_386.png
# Simulando para Ci=387, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_387.png
# Simulando para Ci=388, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_388.png
# Simulando para Ci=389, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_389.png
# Simulando para Ci=390, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_390.png
# Simulando para Ci=391, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_391.png
# Simulando para Ci=392, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_392.png
# Simulando para Ci=393, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_393.png
# Simulando para Ci=394, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_394.png
# Simulando para Ci=395, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_395.png
# Simulando para Ci=396, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_396.png
# Simulando para Ci=397, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_397.png
# Simulando para Ci=398, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_398.png
# Simulando para Ci=399, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_399.png
# Simulando para Ci=400, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_400.png
# Simulando para Ci=401, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_401.png
# Simulando para Ci=402, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_402.png
# Simulando para Ci=403, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_403.png
# Simulando para Ci=404, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_404.png
# Simulando para Ci=405, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_405.png
# Simulando para Ci=406, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_406.png
# Simulando para Ci=407, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_407.png
# Simulando para Ci=408, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_408.png
# Simulando para Ci=409, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_409.png
# Simulando para Ci=410, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_410.png
# Simulando para Ci=411, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_411.png
# Simulando para Ci=412, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_412.png
# Simulando para Ci=413, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_413.png
# Simulando para Ci=414, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_414.png
# Simulando para Ci=415, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_415.png
# Simulando para Ci=416, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_416.png
# Simulando para Ci=417, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_417.png
# Simulando para Ci=418, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_418.png
# Simulando para Ci=419, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_419.png
# Simulando para Ci=420, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_420.png
# Simulando para Ci=421, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_421.png
# Simulando para Ci=422, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_422.png
# Simulando para Ci=423, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_423.png
# Simulando para Ci=424, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_424.png
# Simulando para Ci=425, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_425.png
# Simulando para Ci=426, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_426.png
# Simulando para Ci=427, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_427.png
# Simulando para Ci=428, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_428.png
# Simulando para Ci=429, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_429.png
# Simulando para Ci=430, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_430.png
# Simulando para Ci=431, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_431.png
# Simulando para Ci=432, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_432.png
# Simulando para Ci=433, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_433.png
# Simulando para Ci=434, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_434.png
# Simulando para Ci=435, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_435.png
# Simulando para Ci=436, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_436.png
# Simulando para Ci=437, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_437.png
# Simulando para Ci=438, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_438.png
# Simulando para Ci=439, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_439.png
# Simulando para Ci=440, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_440.png
# Simulando para Ci=441, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_441.png
# Simulando para Ci=442, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_442.png
# Simulando para Ci=443, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_443.png
# Simulando para Ci=444, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_444.png
# Simulando para Ci=445, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_445.png
# Simulando para Ci=446, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_446.png
# Simulando para Ci=447, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_447.png
# Simulando para Ci=448, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_448.png
# Simulando para Ci=449, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_449.png
# Simulando para Ci=450, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_450.png
# Simulando para Ci=451, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_451.png
# Simulando para Ci=452, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_452.png
# Simulando para Ci=453, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_453.png
# Simulando para Ci=454, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_454.png
# Simulando para Ci=455, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_455.png
# Simulando para Ci=456, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_456.png
# Simulando para Ci=457, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_457.png
# Simulando para Ci=458, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_458.png
# Simulando para Ci=459, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_459.png
# Simulando para Ci=460, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_460.png
# Simulando para Ci=461, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_461.png
# Simulando para Ci=462, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_462.png
# Simulando para Ci=463, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_463.png
# Simulando para Ci=464, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_464.png
# Simulando para Ci=465, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_465.png
# Simulando para Ci=466, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_466.png
# Simulando para Ci=467, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_467.png
# Simulando para Ci=468, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_468.png
# Simulando para Ci=469, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_469.png
# Simulando para Ci=470, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_470.png
# Simulando para Ci=471, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_471.png
# Simulando para Ci=472, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_472.png
# Simulando para Ci=473, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_473.png
# Simulando para Ci=474, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_474.png
# Simulando para Ci=475, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_475.png
# Simulando para Ci=476, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_476.png
# Simulando para Ci=477, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_477.png
# Simulando para Ci=478, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_478.png
# Simulando para Ci=479, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_479.png
# Simulando para Ci=480, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_480.png
# Simulando para Ci=481, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_481.png
# Simulando para Ci=482, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_482.png
# Simulando para Ci=483, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_483.png
# Simulando para Ci=484, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_484.png
# Simulando para Ci=485, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_485.png
# Simulando para Ci=486, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_486.png
# Simulando para Ci=487, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_487.png
# Simulando para Ci=488, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_488.png
# Simulando para Ci=489, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_489.png
# Simulando para Ci=490, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_490.png
# Simulando para Ci=491, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_491.png
# Simulando para Ci=492, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_492.png
# Simulando para Ci=493, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_493.png
# Simulando para Ci=494, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_494.png
# Simulando para Ci=495, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_495.png
# Simulando para Ci=496, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_496.png
# Simulando para Ci=497, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_497.png
# Simulando para Ci=498, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_498.png
# Simulando para Ci=499, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_499.png
# Simulando para Ci=500, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_500.png
# Simulando para Ci=501, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_501.png
# Simulando para Ci=502, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_502.png
# Simulando para Ci=503, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_503.png
# Simulando para Ci=504, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_504.png
# Simulando para Ci=505, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_505.png
# Simulando para Ci=506, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_506.png
# Simulando para Ci=507, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_507.png
# Simulando para Ci=508, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_508.png
# Simulando para Ci=509, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_509.png
# Simulando para Ci=510, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_510.png
# Simulando para Ci=511, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_511.png
# Simulando para Ci=512, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_512.png
# Simulando para Ci=513, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_513.png
# Simulando para Ci=514, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_514.png
# Simulando para Ci=515, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_515.png
# Simulando para Ci=516, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_516.png
# Simulando para Ci=517, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_517.png
# Simulando para Ci=518, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_518.png
# Simulando para Ci=519, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_519.png
# Simulando para Ci=520, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_520.png
# Simulando para Ci=521, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_521.png
# Simulando para Ci=522, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_522.png
# Simulando para Ci=523, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_523.png
# Simulando para Ci=524, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_524.png
# Simulando para Ci=525, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_525.png
# Simulando para Ci=526, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_526.png
# Simulando para Ci=527, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_527.png
# Simulando para Ci=528, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_528.png
# Simulando para Ci=529, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_529.png
# Simulando para Ci=530, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_530.png
# Simulando para Ci=531, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_531.png
# Simulando para Ci=532, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_532.png
# Simulando para Ci=533, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_533.png
# Simulando para Ci=534, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_534.png
# Simulando para Ci=535, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_535.png
# Simulando para Ci=536, nu=1.00e-09...
# Guardado: skin224/nu_0.000000001/c_536.png
# Simulando para Ci=537, nu=1.00e-09...
