# %%
# Paqueterías necesarias para la solución 
import scipy.io
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.animation as animation
import os
from multiprocessing import Pool # Estudiar esta cosa (Importante)
def difusion_piel(x, y, t, nu, u_init):
    '''
    Resuelve la ecuación de difusión en una malla bidimensional con condiciones de Dirichlet en la entrada
    y Neumann en las fronteras laterales.
    
    Parámetros:
        x (array):      Coordenadas x de la malla.
        y (array):      Coordenadas 
# convert  de la malla.El manejo de la vía aérea representa uno de los aspectos más críticos en la atención de pacientes en situación de emergencia o con alteraciones del estado de conciencia. Garantizar que el oxígeno llegue de forma adecuada a los pulmones y, por ende, al resto del cuerpo, es una prioridad que puede marcar la diferencia entre la vida y la muerte. Para lograrlo, es indispensable asegurar una vía aérea permeable, estableciendo así un punto de partida fundamental para cualquier intervención médica avanzada. Esta necesidad no es reciente; se han encontrado referencias históricas que demuestran cómo desde el antiguo Egipto, hacia el 3500 a.C., ya se realizaban procedimientos rudimentarios como la traqueostomía para tratar obstrucciones de la vía aérea.

En la actualidad, el abordaje del paciente crítico se estructura mediante protocolos como el ABCDE, en el que la "A" (Airway) destaca la evaluación y control inmediato de la vía aérea. Para ello, se consideran tanto maniobras manuales como técnicas asistidas con dispositivos, partiendo de lo más básico hacia lo más invasivo. Además, se realiza una evaluación secundaria que incluye herramientas como el método SAMPLE y, para identificar posibles dificultades, mnemotecnias como MEMOM, que permiten anticipar complicaciones durante el manejo avanzado.

Las técnicas empleadas varían según el estado del paciente y las condiciones clínicas. Desde el correcto posicionamiento, la elevación del mentón o la tracción mandibular, hasta el uso de dispositivos como la cánula orofaríngea, mascarilla laríngea o el tubo endotraqueal, todas forman parte del arsenal terapéutico del personal de salud. En situaciones extremas, técnicas como la cricotirotomía pueden ser la única opción viable. Por ello, es esencial que el profesional esté entrenado tanto en el reconocimiento oportuno de una vía aérea comprometida como en la ejecución eficaz de los procedimientos necesarios para restablecerla.


        t (int):        Número de pasos de tiempo.
        nu (float):     Coeficiente de difusión.
        u_init (float): Valor inicial de la concentración en la entrada.
    Retorna:
        u_ap (array):   Solución de la ecuación de  difusión en la malla.
    '''
    # Inicializar variables
    m, n  = x.shape                                                             # Dimensiones de la malla
    T     = np.linspace(0, 3600*20, t)                                             # Discretización del tiempo
    dt    = T[1] - T[0]                                                         # Paso de tiempo
    u_ap  = np.zeros([m, n, t])                                                 # Matriz para almacenar la solución
    Gamma = np.zeros([m, n, 9])                                                 # Matriz para almacenar Gammas

    # Revisamos algo así como el CFL
    dx_min = np.min(np.sqrt((x[1:, :] - x[:-1, :])**2 + (y[1:, :] - y[:-1, :])**2))
                                                                                # Tamaño mínimo de dx
    alpha = nu*dt/dx_min**2                                                     # Número de Courant
    print(f"Número de Courant aproximado: {alpha:.2e}")
    if alpha > 0.5:                                                             # Si el número de Courant es muy grande
        print("El número de Courant es muy grande. Ajuste el paso de tiempo o la viscosidad.")
        exit()                       
# convert                                            # Salir del programa


    # Condición inicial
    u_ap[:, :, 0] = 0                                                           # Condición Inicial

    # Calcular Gammas
    L = np.vstack([[0], [0], [2*nu*dt], [0], [2*nu*dt]])                         # Operador Diferencial,  va a pilando las listas para que quede más ordenado. 
    for i in range(1, m-1):
        for j in range(1, n-1):
            dx = np.array([
                x[i + 1, j], x[i + 1, j + 1], x[i, j + 1], x[i - 1, j + 1],
                x[i - 1, j], x[i - 1, j - 1], x[i, j - 1], x[i + 1, j - 1]
                ]) - x[i, j]                                                    # Todos los dx para el nodo central
        
            dy = np.array([
                y[i + 1, j], y[i + 1, j + 1], y[i, j + 1], y[i - 1, j + 1],
                y[i - 1, j], y[i - 1, j - 1], y[i, j - 1], y[i + 1, j - 1]
                ]) - y[i, j]                                                    # Todos los dy para el nodo central
        
            M = np.vstack([[dx], [dy], [dx**2], [dx*dy], [dy**2]])              # Se crea la matriz de coeficientes
            M = np.linalg.pinv(M)                                               # Se calcula la pseudoinversa (Morse-Penrose)
            YY = M@L                                                            # Se calculan las primeras Gammas
            Gem = np.concatenate(([-np.sum(YY)], YY.flatten()))                 # Se calculan todas las Gammas
            Gamma[i, j, :] = Gem                                                # Se almacenan las Gammas

    # Resolver la ecuación diferencial
    for k in range(1, t):      
        nucleo  = u_ap[1:-1, 1:-1, k-1]                                         # El nucleo es el nodo central
        pesos   = Gamma[1:-1, 1:-1, :]                                          # Los pesos son las Gammas para el esténcil
        vecinos = np.array([
            pesos[:, :, 0] * nucleo,
            pesos[:, :, 1] * u_ap[2:  , 1:-1, k-1],
            pesos[:, :, 2] * u_ap[2:  , 2:  , k-1],
            pesos[:, :, 3] * u_ap[1:-1, 2:  , k-1],
            pesos[:, :, 4] * u_ap[0:-2, 2:  , k-1],
            pesos[:, :, 5] * u_ap[0:-2, 1:-1, k-1],
            pesos[:, :, 6] * u_ap[0:-2, 0:-2, k-1],
            pesos[:, :, 7] * u_ap[1:-1, 0:-2, k-1],
            pesos[:, :, 8] * u_ap[2:  , 0:-2, k-1],
        ])                                                                     # Se calculan las contribuciones de los vecinos
        u_ap[1:-1, 1:-1, k] = nucleo + np.sum(vecinos, axis = 0)               # Se calcula el nuevo paso de tiempo

        # Condiciones de frontera de Dirichlet en la entrada
        u_ap[:,   0, k] = u_init                                               # Condición de Dirichlet en la entrada

        # Condiciones de Neumann (no
# convert  flujo) en las fronteras laterales
        # Calculadas de forma clásica con en Diferencias Finitas Clásicas
        u_ap[:,   n-1, k] = u_ap[:,   n-2, k]                                  # Condición de Neumann en la pared inferior
        u_ap[m-1, :,   k] = u_ap[m-2, :,   k]                                  # Condición de Neumann en la pared izquierda
        u_ap[0,   :,   k] = u_ap[1,   :,   k]                                  # Condición de Neumann en la pared derecha
    
    return u_ap
# Generación de la base de datos 

# Cargar datos de la malla
datos  = scipy.io.loadmat('piel224.mat')

# Definir los parámetros del problem (esto es lo que va a variar en el problema)
x, y   = datos["x"], datos["y"]
t      = 500
output_dir = '/home/letmitaf/Escritorio/Difusion_images_4'
# Resolver la ecuación de difusión y crear el gif
# Generación de la base de datos 
# Resolver la ecuación de difusión y crear el gif
  # === Función del proceso paralelo ===
def run_case(params):
    ss, j = params
    nu = ss * 1e-9
    u_init = j

    print(f"Simulando para Ci={j}, nu={nu}...")
    u_ap = difusion_piel(x, y, t, nu, u_init)

    if u_ap is None:
        return

    # Crear carpeta para el valor actual de nu
    carpeta_nu = os.path.join(output_dir, f"nu_{nu:.9f}")
    os.makedirs(carpeta_nu, exist_ok=True)  # Asegura que la carpeta exista

    # Crear y guardar el gráfico
    plt.figure(figsize=(8, 6))
    plt.pcolormesh(x, y, u_ap[:, :, t - 1], shading='auto', cmap='cool_r',
                   facecolor='lightgray', vmin=0, vmax=900)
    #_plt.axis('equal')
    plt.axis('off')  # Oculta todos los ejes y ticks

    filename = os.path.join(carpeta_nu, f"c_{j:03d}.png")  # Formato: c_001.png
#    plt.savefig(filename, dpi=75)
    plt.savefig(filename, dpi=75, bbox_inches='tight', pad_inches=0)

    plt.close()
    print(f"Guardado: {filename}")
#def run_case(params):
 #   ss, j = params
  #  nu = ss * 1e-9
  #  u_init = j

   # print(f"Simulando para Ci={j}, nu={nu}...")
   # u_ap = difusion_piel(x, y, t, nu, u_init)

   # if u_ap is None:
    #    return

   # plt.figure(figsize=(8, 6))
   # plt.pcolormesh(x, y, u_ap[:, :, t - 1], shading='auto', cmap='cool_r',
    #               facecolor='lightgray', vmin=0, vmax=100)
    #plt.axis('equal')
    #filename = os.path.join(output_dir, f"Ci_{j}_nu_{ss}e-8.png")
    #plt.savefig(filename, dpi=75) 
    #plt.close()
    #print(f"Guardado: {filename}")

# === Ejecutar en paralelo ===
if __name__ == "__main__":
    combinations = [(i, j) for i in range(1, 201) for j in range(1, 901)]
    with Pool(processes=1) as pool:
        pool.map(run_case, combinations)

# Valores faltantes de 43 a 900 en el range(43,900)
# Out:
# Simulando para Ci=1, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# /tmp/ipykernel_8725/260543406.py:128: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x, y, u_ap[:, :, t - 1], shading='auto', cmap='cool_r',
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_001.png
# Simulando para Ci=2, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_002.png
# Simulando para Ci=3, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_003.png
# Simulando para Ci=4, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_004.png
# Simulando para Ci=5, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_005.png
# Simulando para Ci=6, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_006.png
# Simulando para Ci=7, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_007.png
# Simulando para Ci=8, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_008.png
# Simulando para Ci=9, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_009.png
# Simulando para Ci=10, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_010.png
# Simulando para Ci=11, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_011.png
# Simulando para Ci=12, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_012.png
# Simulando para Ci=13, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_013.png
# Simulando para Ci=14, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_014.png
# Simulando para Ci=15, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_015.png
# Simulando para Ci=16, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_016.png
# Simulando para Ci=17, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_017.png
# Simulando para Ci=18, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_018.png
# Simulando para Ci=19, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_019.png
# Simulando para Ci=20, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_020.png
# Simulando para Ci=21, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_021.png
# Simulando para Ci=22, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_022.png
# Simulando para Ci=23, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_023.png
# Simulando para Ci=24, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_024.png
# Simulando para Ci=25, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_025.png
# Simulando para Ci=26, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_026.png
# Simulando para Ci=27, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_027.png
# Simulando para Ci=28, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_028.png
# Simulando para Ci=29, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_029.png
# Simulando para Ci=30, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_030.png
# Simulando para Ci=31, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_031.png
# Simulando para Ci=32, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_032.png
# Simulando para Ci=33, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_033.png
# Simulando para Ci=34, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_034.png
# Simulando para Ci=35, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_035.png
# Simulando para Ci=36, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_036.png
# Simulando para Ci=37, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_037.png
# Simulando para Ci=38, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_038.png
# Simulando para Ci=39, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_039.png
# Simulando para Ci=40, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_040.png
# Simulando para Ci=41, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_041.png
# Simulando para Ci=42, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_042.png
# Simulando para Ci=43, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_043.png
# Simulando para Ci=44, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_044.png
# Simulando para Ci=45, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_045.png
# Simulando para Ci=46, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_046.png
# Simulando para Ci=47, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_047.png
# Simulando para Ci=48, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_048.png
# Simulando para Ci=49, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_049.png
# Simulando para Ci=50, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_050.png
# Simulando para Ci=51, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_051.png
# Simulando para Ci=52, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_052.png
# Simulando para Ci=53, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_053.png
# Simulando para Ci=54, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_054.png
# Simulando para Ci=55, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_055.png
# Simulando para Ci=56, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_056.png
# Simulando para Ci=57, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_057.png
# Simulando para Ci=58, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_058.png
# Simulando para Ci=59, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_059.png
# Simulando para Ci=60, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_060.png
# Simulando para Ci=61, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_061.png
# Simulando para Ci=62, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_062.png
# Simulando para Ci=63, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_063.png
# Simulando para Ci=64, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_064.png
# Simulando para Ci=65, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_065.png
# Simulando para Ci=66, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_066.png
# Simulando para Ci=67, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_067.png
# Simulando para Ci=68, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_068.png
# Simulando para Ci=69, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_069.png
# Simulando para Ci=70, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_070.png
# Simulando para Ci=71, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_071.png
# Simulando para Ci=72, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_072.png
# Simulando para Ci=73, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_073.png
# Simulando para Ci=74, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_074.png
# Simulando para Ci=75, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_075.png
# Simulando para Ci=76, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_076.png
# Simulando para Ci=77, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_077.png
# Simulando para Ci=78, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_078.png
# Simulando para Ci=79, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_079.png
# Simulando para Ci=80, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_080.png
# Simulando para Ci=81, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_081.png
# Simulando para Ci=82, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_082.png
# Simulando para Ci=83, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_083.png
# Simulando para Ci=84, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_084.png
# Simulando para Ci=85, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_085.png
# Simulando para Ci=86, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_086.png
# Simulando para Ci=87, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_087.png
# Simulando para Ci=88, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_088.png
# Simulando para Ci=89, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_089.png
# Simulando para Ci=90, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_090.png
# Simulando para Ci=91, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_091.png
# Simulando para Ci=92, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_092.png
# Simulando para Ci=93, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_093.png
# Simulando para Ci=94, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_094.png
# Simulando para Ci=95, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_095.png
# Simulando para Ci=96, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_096.png
# Simulando para Ci=97, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_097.png
# Simulando para Ci=98, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_098.png
# Simulando para Ci=99, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_099.png
# Simulando para Ci=100, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_100.png
# Simulando para Ci=101, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_101.png
# Simulando para Ci=102, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_102.png
# Simulando para Ci=103, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_103.png
# Simulando para Ci=104, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_104.png
# Simulando para Ci=105, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_105.png
# Simulando para Ci=106, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_106.png
# Simulando para Ci=107, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_107.png
# Simulando para Ci=108, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_108.png
# Simulando para Ci=109, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_109.png
# Simulando para Ci=110, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_110.png
# Simulando para Ci=111, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_111.png
# Simulando para Ci=112, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_112.png
# Simulando para Ci=113, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_113.png
# Simulando para Ci=114, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_114.png
# Simulando para Ci=115, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_115.png
# Simulando para Ci=116, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_116.png
# Simulando para Ci=117, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_117.png
# Simulando para Ci=118, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_118.png
# Simulando para Ci=119, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_119.png
# Simulando para Ci=120, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_120.png
# Simulando para Ci=121, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_121.png
# Simulando para Ci=122, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_122.png
# Simulando para Ci=123, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_123.png
# Simulando para Ci=124, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_124.png
# Simulando para Ci=125, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_125.png
# Simulando para Ci=126, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_126.png
# Simulando para Ci=127, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_127.png
# Simulando para Ci=128, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_128.png
# Simulando para Ci=129, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_129.png
# Simulando para Ci=130, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_130.png
# Simulando para Ci=131, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_131.png
# Simulando para Ci=132, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_132.png
# Simulando para Ci=133, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_133.png
# Simulando para Ci=134, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_134.png
# Simulando para Ci=135, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_135.png
# Simulando para Ci=136, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_136.png
# Simulando para Ci=137, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_137.png
# Simulando para Ci=138, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_138.png
# Simulando para Ci=139, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_139.png
# Simulando para Ci=140, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_140.png
# Simulando para Ci=141, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_141.png
# Simulando para Ci=142, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_142.png
# Simulando para Ci=143, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_143.png
# Simulando para Ci=144, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_144.png
# Simulando para Ci=145, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_145.png
# Simulando para Ci=146, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_146.png
# Simulando para Ci=147, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_147.png
# Simulando para Ci=148, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_148.png
# Simulando para Ci=149, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_149.png
# Simulando para Ci=150, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_150.png
# Simulando para Ci=151, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_151.png
# Simulando para Ci=152, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_152.png
# Simulando para Ci=153, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_153.png
# Simulando para Ci=154, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_154.png
# Simulando para Ci=155, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_155.png
# Simulando para Ci=156, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_156.png
# Simulando para Ci=157, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_157.png
# Simulando para Ci=158, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_158.png
# Simulando para Ci=159, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_159.png
# Simulando para Ci=160, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_160.png
# Simulando para Ci=161, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_161.png
# Simulando para Ci=162, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_162.png
# Simulando para Ci=163, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_163.png
# Simulando para Ci=164, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_164.png
# Simulando para Ci=165, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_165.png
# Simulando para Ci=166, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_166.png
# Simulando para Ci=167, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_167.png
# Simulando para Ci=168, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_168.png
# Simulando para Ci=169, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_169.png
# Simulando para Ci=170, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_170.png
# Simulando para Ci=171, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_171.png
# Simulando para Ci=172, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_172.png
# Simulando para Ci=173, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_173.png
# Simulando para Ci=174, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_174.png
# Simulando para Ci=175, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_175.png
# Simulando para Ci=176, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_176.png
# Simulando para Ci=177, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_177.png
# Simulando para Ci=178, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_178.png
# Simulando para Ci=179, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_179.png
# Simulando para Ci=180, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_180.png
# Simulando para Ci=181, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_181.png
# Simulando para Ci=182, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_182.png
# Simulando para Ci=183, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_183.png
# Simulando para Ci=184, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_184.png
# Simulando para Ci=185, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_185.png
# Simulando para Ci=186, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_186.png
# Simulando para Ci=187, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_187.png
# Simulando para Ci=188, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_188.png
# Simulando para Ci=189, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_189.png
# Simulando para Ci=190, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_190.png
# Simulando para Ci=191, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_191.png
# Simulando para Ci=192, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_192.png
# Simulando para Ci=193, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_193.png
# Simulando para Ci=194, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_194.png
# Simulando para Ci=195, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_195.png
# Simulando para Ci=196, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_196.png
# Simulando para Ci=197, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_197.png
# Simulando para Ci=198, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_198.png
# Simulando para Ci=199, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_199.png
# Simulando para Ci=200, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_200.png
# Simulando para Ci=201, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_201.png
# Simulando para Ci=202, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_202.png
# Simulando para Ci=203, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_203.png
# Simulando para Ci=204, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_204.png
# Simulando para Ci=205, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_205.png
# Simulando para Ci=206, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_206.png
# Simulando para Ci=207, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_207.png
# Simulando para Ci=208, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_208.png
# Simulando para Ci=209, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_209.png
# Simulando para Ci=210, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_210.png
# Simulando para Ci=211, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_211.png
# Simulando para Ci=212, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_212.png
# Simulando para Ci=213, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_213.png
# Simulando para Ci=214, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_214.png
# Simulando para Ci=215, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_215.png
# Simulando para Ci=216, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_216.png
# Simulando para Ci=217, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_217.png
# Simulando para Ci=218, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_218.png
# Simulando para Ci=219, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_219.png
# Simulando para Ci=220, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_220.png
# Simulando para Ci=221, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_221.png
# Simulando para Ci=222, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_222.png
# Simulando para Ci=223, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_223.png
# Simulando para Ci=224, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_224.png
# Simulando para Ci=225, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_225.png
# Simulando para Ci=226, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_226.png
# Simulando para Ci=227, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_227.png
# Simulando para Ci=228, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_228.png
# Simulando para Ci=229, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_229.png
# Simulando para Ci=230, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_230.png
# Simulando para Ci=231, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_231.png
# Simulando para Ci=232, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_232.png
# Simulando para Ci=233, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_233.png
# Simulando para Ci=234, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_234.png
# Simulando para Ci=235, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_235.png
# Simulando para Ci=236, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_236.png
# Simulando para Ci=237, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_237.png
# Simulando para Ci=238, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_238.png
# Simulando para Ci=239, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_239.png
# Simulando para Ci=240, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_240.png
# Simulando para Ci=241, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_241.png
# Simulando para Ci=242, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_242.png
# Simulando para Ci=243, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_243.png
# Simulando para Ci=244, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_244.png
# Simulando para Ci=245, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_245.png
# Simulando para Ci=246, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_246.png
# Simulando para Ci=247, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_247.png
# Simulando para Ci=248, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_248.png
# Simulando para Ci=249, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_249.png
# Simulando para Ci=250, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_250.png
# Simulando para Ci=251, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_251.png
# Simulando para Ci=252, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_252.png
# Simulando para Ci=253, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_253.png
# Simulando para Ci=254, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_254.png
# Simulando para Ci=255, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_255.png
# Simulando para Ci=256, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_256.png
# Simulando para Ci=257, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_257.png
# Simulando para Ci=258, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_258.png
# Simulando para Ci=259, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_259.png
# Simulando para Ci=260, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_260.png
# Simulando para Ci=261, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_261.png
# Simulando para Ci=262, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_262.png
# Simulando para Ci=263, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_263.png
# Simulando para Ci=264, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_264.png
# Simulando para Ci=265, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_265.png
# Simulando para Ci=266, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_266.png
# Simulando para Ci=267, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_267.png
# Simulando para Ci=268, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_268.png
# Simulando para Ci=269, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_269.png
# Simulando para Ci=270, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_270.png
# Simulando para Ci=271, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_271.png
# Simulando para Ci=272, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_272.png
# Simulando para Ci=273, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_273.png
# Simulando para Ci=274, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_274.png
# Simulando para Ci=275, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_275.png
# Simulando para Ci=276, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_276.png
# Simulando para Ci=277, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_277.png
# Simulando para Ci=278, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_278.png
# Simulando para Ci=279, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_279.png
# Simulando para Ci=280, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_280.png
# Simulando para Ci=281, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_281.png
# Simulando para Ci=282, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_282.png
# Simulando para Ci=283, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_283.png
# Simulando para Ci=284, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_284.png
# Simulando para Ci=285, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_285.png
# Simulando para Ci=286, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_286.png
# Simulando para Ci=287, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_287.png
# Simulando para Ci=288, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_288.png
# Simulando para Ci=289, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_289.png
# Simulando para Ci=290, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_290.png
# Simulando para Ci=291, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_291.png
# Simulando para Ci=292, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_292.png
# Simulando para Ci=293, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_293.png
# Simulando para Ci=294, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_294.png
# Simulando para Ci=295, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_295.png
# Simulando para Ci=296, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_296.png
# Simulando para Ci=297, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_297.png
# Simulando para Ci=298, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_298.png
# Simulando para Ci=299, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_299.png
# Simulando para Ci=300, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_300.png
# Simulando para Ci=301, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_301.png
# Simulando para Ci=302, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_302.png
# Simulando para Ci=303, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_303.png
# Simulando para Ci=304, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_304.png
# Simulando para Ci=305, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_305.png
# Simulando para Ci=306, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_306.png
# Simulando para Ci=307, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_307.png
# Simulando para Ci=308, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_308.png
# Simulando para Ci=309, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_309.png
# Simulando para Ci=310, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_310.png
# Simulando para Ci=311, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_311.png
# Simulando para Ci=312, nu=1e-09...
# Número de Courant aproximado: 5.60e-03
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000001/c_312.png
# ...
# Simulando para Ci=765, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_765.png
# Simulando para Ci=766, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_766.png
# Simulando para Ci=767, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_767.png
# Simulando para Ci=768, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_768.png
# Simulando para Ci=769, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_769.png
# Simulando para Ci=770, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_770.png
# Simulando para Ci=771, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_771.png
# Simulando para Ci=772, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_772.png
# Simulando para Ci=773, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_773.png
# Simulando para Ci=774, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_774.png
# Simulando para Ci=775, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_775.png
# Simulando para Ci=776, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_776.png
# Simulando para Ci=777, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_777.png
# Simulando para Ci=778, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_778.png
# Simulando para Ci=779, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_779.png
# Simulando para Ci=780, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_780.png
# Simulando para Ci=781, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_781.png
# Simulando para Ci=782, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_782.png
# Simulando para Ci=783, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_783.png
# Simulando para Ci=784, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_784.png
# Simulando para Ci=785, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_785.png
# Simulando para Ci=786, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_786.png
# Simulando para Ci=787, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_787.png
# Simulando para Ci=788, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_788.png
# Simulando para Ci=789, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_789.png
# Simulando para Ci=790, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_790.png
# Simulando para Ci=791, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_791.png
# Simulando para Ci=792, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_792.png
# Simulando para Ci=793, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_793.png
# Simulando para Ci=794, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_794.png
# Simulando para Ci=795, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_795.png
# Simulando para Ci=796, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_796.png
# Simulando para Ci=797, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_797.png
# Simulando para Ci=798, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_798.png
# Simulando para Ci=799, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_799.png
# Simulando para Ci=800, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_800.png
# Simulando para Ci=801, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_801.png
# Simulando para Ci=802, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_802.png
# Simulando para Ci=803, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_803.png
# Simulando para Ci=804, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_804.png
# Simulando para Ci=805, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_805.png
# Simulando para Ci=806, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_806.png
# Simulando para Ci=807, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_807.png
# Simulando para Ci=808, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_808.png
# Simulando para Ci=809, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_809.png
# Simulando para Ci=810, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_810.png
# Simulando para Ci=811, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_811.png
# Simulando para Ci=812, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_812.png
# Simulando para Ci=813, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_813.png
# Simulando para Ci=814, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_814.png
# Simulando para Ci=815, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_815.png
# Simulando para Ci=816, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_816.png
# Simulando para Ci=817, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_817.png
# Simulando para Ci=818, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_818.png
# Simulando para Ci=819, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_819.png
# Simulando para Ci=820, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_820.png
# Simulando para Ci=821, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_821.png
# Simulando para Ci=822, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_822.png
# Simulando para Ci=823, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_823.png
# Simulando para Ci=824, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_824.png
# Simulando para Ci=825, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_825.png
# Simulando para Ci=826, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_826.png
# Simulando para Ci=827, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_827.png
# Simulando para Ci=828, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_828.png
# Simulando para Ci=829, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_829.png
# Simulando para Ci=830, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_830.png
# Simulando para Ci=831, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_831.png
# Simulando para Ci=832, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_832.png
# Simulando para Ci=833, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_833.png
# Simulando para Ci=834, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_834.png
# Simulando para Ci=835, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_835.png
# Simulando para Ci=836, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_836.png
# Simulando para Ci=837, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_837.png
# Simulando para Ci=838, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_838.png
# Simulando para Ci=839, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_839.png
# Simulando para Ci=840, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_840.png
# Simulando para Ci=841, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_841.png
# Simulando para Ci=842, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_842.png
# Simulando para Ci=843, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_843.png
# Simulando para Ci=844, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_844.png
# Simulando para Ci=845, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_845.png
# Simulando para Ci=846, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_846.png
# Simulando para Ci=847, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_847.png
# Simulando para Ci=848, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_848.png
# Simulando para Ci=849, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_849.png
# Simulando para Ci=850, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_850.png
# Simulando para Ci=851, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_851.png
# Simulando para Ci=852, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_852.png
# Simulando para Ci=853, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_853.png
# Simulando para Ci=854, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_854.png
# Simulando para Ci=855, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_855.png
# Simulando para Ci=856, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_856.png
# Simulando para Ci=857, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_857.png
# Simulando para Ci=858, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_858.png
# Simulando para Ci=859, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_859.png
# Simulando para Ci=860, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_860.png
# Simulando para Ci=861, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_861.png
# Simulando para Ci=862, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_862.png
# Simulando para Ci=863, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_863.png
# Simulando para Ci=864, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_864.png
# Simulando para Ci=865, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_865.png
# Simulando para Ci=866, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_866.png
# Simulando para Ci=867, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_867.png
# Simulando para Ci=868, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/nu_0.000000002/c_868.png
# Simulando para Ci=869, nu=2e-09...
# Número de Courant aproximado: 1.12e-02
