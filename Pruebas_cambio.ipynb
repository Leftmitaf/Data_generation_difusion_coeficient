# %%
# Paqueterías necesarias para la solución 
import scipy.io
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.animation as animation
import os
from multiprocessing import Pool # Estudiar esta cosa (Importante)
def difusion_piel(x, y, t, nu, u_init):
    '''
    Resuelve la ecuación de difusión en una malla bidimensional con condiciones de Dirichlet en la entrada
    y Neumann en las fronteras laterales.
    
    Parámetros:
        x (array):      Coordenadas x de la malla.
        y (array):      Coordenadas 
# convert  de la malla.El manejo de la vía aérea representa uno de los aspectos más críticos en la atención de pacientes en situación de emergencia o con alteraciones del estado de conciencia. Garantizar que el oxígeno llegue de forma adecuada a los pulmones y, por ende, al resto del cuerpo, es una prioridad que puede marcar la diferencia entre la vida y la muerte. Para lograrlo, es indispensable asegurar una vía aérea permeable, estableciendo así un punto de partida fundamental para cualquier intervención médica avanzada. Esta necesidad no es reciente; se han encontrado referencias históricas que demuestran cómo desde el antiguo Egipto, hacia el 3500 a.C., ya se realizaban procedimientos rudimentarios como la traqueostomía para tratar obstrucciones de la vía aérea.

En la actualidad, el abordaje del paciente crítico se estructura mediante protocolos como el ABCDE, en el que la "A" (Airway) destaca la evaluación y control inmediato de la vía aérea. Para ello, se consideran tanto maniobras manuales como técnicas asistidas con dispositivos, partiendo de lo más básico hacia lo más invasivo. Además, se realiza una evaluación secundaria que incluye herramientas como el método SAMPLE y, para identificar posibles dificultades, mnemotecnias como MEMOM, que permiten anticipar complicaciones durante el manejo avanzado.

Las técnicas empleadas varían según el estado del paciente y las condiciones clínicas. Desde el correcto posicionamiento, la elevación del mentón o la tracción mandibular, hasta el uso de dispositivos como la cánula orofaríngea, mascarilla laríngea o el tubo endotraqueal, todas forman parte del arsenal terapéutico del personal de salud. En situaciones extremas, técnicas como la cricotirotomía pueden ser la única opción viable. Por ello, es esencial que el profesional esté entrenado tanto en el reconocimiento oportuno de una vía aérea comprometida como en la ejecución eficaz de los procedimientos necesarios para restablecerla.


        t (int):        Número de pasos de tiempo.
        nu (float):     Coeficiente de difusión.
        u_init (float): Valor inicial de la concentración en la entrada.
    Retorna:
        u_ap (array):   Solución de la ecuación de  difusión en la malla.
    '''
    # Inicializar variables
    m, n  = x.shape                                                             # Dimensiones de la malla
    T     = np.linspace(0, 3600*20, t)                                             # Discretización del tiempo
    dt    = T[1] - T[0]                                                         # Paso de tiempo
    u_ap  = np.zeros([m, n, t])                                                 # Matriz para almacenar la solución
    Gamma = np.zeros([m, n, 9])                                                 # Matriz para almacenar Gammas

    # Revisamos algo así como el CFL
    dx_min = np.min(np.sqrt((x[1:, :] - x[:-1, :])**2 + (y[1:, :] - y[:-1, :])**2))
                                                                                # Tamaño mínimo de dx
    alpha = nu*dt/dx_min**2                                                     # Número de Courant
    print(f"Número de Courant aproximado: {alpha:.2e}")
    if alpha > 0.5:                                                             # Si el número de Courant es muy grande
        print("El número de Courant es muy grande. Ajuste el paso de tiempo o la viscosidad.")
        exit()                       
# convert                                            # Salir del programa


    # Condición inicial
    u_ap[:, :, 0] = 0                                                           # Condición Inicial

    # Calcular Gammas
    L = np.vstack([[0], [0], [2*nu*dt], [0], [2*nu*dt]])                         # Operador Diferencial,  va a pilando las listas para que quede más ordenado. 
    for i in range(1, m-1):
        for j in range(1, n-1):
            dx = np.array([
                x[i + 1, j], x[i + 1, j + 1], x[i, j + 1], x[i - 1, j + 1],
                x[i - 1, j], x[i - 1, j - 1], x[i, j - 1], x[i + 1, j - 1]
                ]) - x[i, j]                                                    # Todos los dx para el nodo central
        
            dy = np.array([
                y[i + 1, j], y[i + 1, j + 1], y[i, j + 1], y[i - 1, j + 1],
                y[i - 1, j], y[i - 1, j - 1], y[i, j - 1], y[i + 1, j - 1]
                ]) - y[i, j]                                                    # Todos los dy para el nodo central
        
            M = np.vstack([[dx], [dy], [dx**2], [dx*dy], [dy**2]])              # Se crea la matriz de coeficientes
            M = np.linalg.pinv(M)                                               # Se calcula la pseudoinversa (Morse-Penrose)
            YY = M@L                                                            # Se calculan las primeras Gammas
            Gem = np.concatenate(([-np.sum(YY)], YY.flatten()))                 # Se calculan todas las Gammas
            Gamma[i, j, :] = Gem                                                # Se almacenan las Gammas

    # Resolver la ecuación diferencial
    for k in range(1, t):      
        nucleo  = u_ap[1:-1, 1:-1, k-1]                                         # El nucleo es el nodo central
        pesos   = Gamma[1:-1, 1:-1, :]                                          # Los pesos son las Gammas para el esténcil
        vecinos = np.array([
            pesos[:, :, 0] * nucleo,
            pesos[:, :, 1] * u_ap[2:  , 1:-1, k-1],
            pesos[:, :, 2] * u_ap[2:  , 2:  , k-1],
            pesos[:, :, 3] * u_ap[1:-1, 2:  , k-1],
            pesos[:, :, 4] * u_ap[0:-2, 2:  , k-1],
            pesos[:, :, 5] * u_ap[0:-2, 1:-1, k-1],
            pesos[:, :, 6] * u_ap[0:-2, 0:-2, k-1],
            pesos[:, :, 7] * u_ap[1:-1, 0:-2, k-1],
            pesos[:, :, 8] * u_ap[2:  , 0:-2, k-1],
        ])                                                                     # Se calculan las contribuciones de los vecinos
        u_ap[1:-1, 1:-1, k] = nucleo + np.sum(vecinos, axis = 0)               # Se calcula el nuevo paso de tiempo

        # Condiciones de frontera de Dirichlet en la entrada
        u_ap[:,   0, k] = u_init                                               # Condición de Dirichlet en la entrada

        # Condiciones de Neumann (no
# convert  flujo) en las fronteras laterales
        # Calculadas de forma clásica con en Diferencias Finitas Clásicas
        u_ap[:,   n-1, k] = u_ap[:,   n-2, k]                                  # Condición de Neumann en la pared inferior
        u_ap[m-1, :,   k] = u_ap[m-2, :,   k]                                  # Condición de Neumann en la pared izquierda
        u_ap[0,   :,   k] = u_ap[1,   :,   k]                                  # Condición de Neumann en la pared derecha
    
    return u_ap
# Generación de la base de datos 

# Cargar datos de la malla
datos  = scipy.io.loadmat('piel224.mat')

# Definir los parámetros del problem (esto es lo que va a variar en el problema)
x, y   = datos["x"], datos["y"]
t      = 1000
output_dir = '/home/letmitaf/Escritorio/Difusion_images_4'
# Resolver la ecuación de difusión y crear el gif
# Generación de la base de datos 
# Resolver la ecuación de difusión y crear el gif
  # === Función del proceso paralelo ===
def run_case(params):
    ss, j = params
    nu = ss * 1e-9
    u_init = j

    print(f"Simulando para Ci={j}, nu={ss}e-8...")
    u_ap = difusion_piel(x, y, t, nu, u_init)

    if u_ap is None:
        return

    plt.figure(figsize=(8, 6))
    plt.pcolormesh(x, y, u_ap[:, :, t - 1], shading='auto', cmap='cool_r',
                   facecolor='lightgray', vmin=0, vmax=100)
    plt.axis('equal')
    filename = os.path.join(output_dir, f"Ci_{j}_nu_{ss}e-8.png")
    plt.savefig(filename, dpi=300) 
    plt.close()
    print(f"Guardado: {filename}")

# === Ejecutar en paralelo ===
if __name__ == "__main__":
    combinations = [(i, j) for i in range(43, 60) for j in range(1, 100)]
    with Pool(processes=os.cpu_count()) as pool:
        pool.map(run_case, combinations)

# Valores faltantes de 43 a 900 en el range(43,900)
# Out:
# Simulando para Ci=14, nu=45e-8...Simulando para Ci=1, nu=43e-8...
#
# Número de Courant aproximado: 1.26e-01Número de Courant aproximado: 1.20e-01
# /tmp/ipykernel_5879/1664022227.py:123: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x, y, u_ap[:, :, t - 1], shading='auto', cmap='cool_r',
# /tmp/ipykernel_5879/1664022227.py:123: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(x, y, u_ap[:, :, t - 1], shading='auto', cmap='cool_r',
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_1_nu_43e-8.png
# Simulando para Ci=2, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_14_nu_45e-8.png
# Simulando para Ci=15, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_15_nu_45e-8.png
# Simulando para Ci=16, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_2_nu_43e-8.png
# Simulando para Ci=3, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_16_nu_45e-8.png
# Simulando para Ci=17, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_3_nu_43e-8.png
# Simulando para Ci=4, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_17_nu_45e-8.png
# Simulando para Ci=18, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_4_nu_43e-8.png
# Simulando para Ci=5, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_18_nu_45e-8.png
# Simulando para Ci=19, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_5_nu_43e-8.png
# Simulando para Ci=6, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_19_nu_45e-8.png
# Simulando para Ci=20, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_6_nu_43e-8.png
# Simulando para Ci=7, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_20_nu_45e-8.png
# Simulando para Ci=21, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_7_nu_43e-8.png
# Simulando para Ci=8, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_21_nu_45e-8.png
# Simulando para Ci=22, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_8_nu_43e-8.png
# Simulando para Ci=9, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_9_nu_43e-8.png
# Simulando para Ci=10, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_22_nu_45e-8.png
# Simulando para Ci=23, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_10_nu_43e-8.png
# Simulando para Ci=11, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_23_nu_45e-8.png
# Simulando para Ci=24, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_24_nu_45e-8.png
# Simulando para Ci=25, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_11_nu_43e-8.png
# Simulando para Ci=12, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_25_nu_45e-8.png
# Simulando para Ci=26, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_12_nu_43e-8.png
# Simulando para Ci=13, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_26_nu_45e-8.png
# Simulando para Ci=27, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_13_nu_43e-8.png
# Simulando para Ci=14, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_27_nu_45e-8.png
# Simulando para Ci=28, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_14_nu_43e-8.png
# Simulando para Ci=15, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_28_nu_45e-8.png
# Simulando para Ci=29, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_15_nu_43e-8.png
# Simulando para Ci=16, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_29_nu_45e-8.png
# Simulando para Ci=30, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_16_nu_43e-8.png
# Simulando para Ci=17, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_30_nu_45e-8.png
# Simulando para Ci=31, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_17_nu_43e-8.png
# Simulando para Ci=18, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_31_nu_45e-8.png
# Simulando para Ci=32, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_18_nu_43e-8.png
# Simulando para Ci=19, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_32_nu_45e-8.png
# Simulando para Ci=33, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_19_nu_43e-8.png
# Simulando para Ci=20, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_33_nu_45e-8.png
# Simulando para Ci=34, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_20_nu_43e-8.png
# Simulando para Ci=21, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_34_nu_45e-8.png
# Simulando para Ci=35, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_21_nu_43e-8.png
# Simulando para Ci=22, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_35_nu_45e-8.png
# Simulando para Ci=36, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_22_nu_43e-8.png
# Simulando para Ci=23, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_36_nu_45e-8.png
# Simulando para Ci=37, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_23_nu_43e-8.png
# Simulando para Ci=24, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_37_nu_45e-8.png
# Simulando para Ci=38, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_24_nu_43e-8.png
# Simulando para Ci=25, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_38_nu_45e-8.png
# Simulando para Ci=39, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_25_nu_43e-8.png
# Simulando para Ci=26, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_39_nu_45e-8.png
# Simulando para Ci=40, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_26_nu_43e-8.png
# Simulando para Ci=27, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_40_nu_45e-8.png
# Simulando para Ci=41, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_27_nu_43e-8.png
# Simulando para Ci=28, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_41_nu_45e-8.png
# Simulando para Ci=42, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_28_nu_43e-8.png
# Simulando para Ci=29, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_42_nu_45e-8.png
# Simulando para Ci=43, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_29_nu_43e-8.png
# Simulando para Ci=30, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_43_nu_45e-8.png
# Simulando para Ci=44, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_30_nu_43e-8.png
# Simulando para Ci=31, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_44_nu_45e-8.png
# Simulando para Ci=45, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_31_nu_43e-8.png
# Simulando para Ci=32, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_45_nu_45e-8.png
# Simulando para Ci=46, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_32_nu_43e-8.png
# Simulando para Ci=33, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_46_nu_45e-8.png
# Simulando para Ci=47, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_33_nu_43e-8.png
# Simulando para Ci=34, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_47_nu_45e-8.png
# Simulando para Ci=48, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_34_nu_43e-8.png
# Simulando para Ci=35, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_48_nu_45e-8.png
# Simulando para Ci=49, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_35_nu_43e-8.png
# Simulando para Ci=36, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_49_nu_45e-8.png
# Simulando para Ci=50, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_36_nu_43e-8.png
# Simulando para Ci=37, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_50_nu_45e-8.png
# Simulando para Ci=51, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_37_nu_43e-8.png
# Simulando para Ci=38, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_51_nu_45e-8.png
# Simulando para Ci=52, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_52_nu_45e-8.png
# Simulando para Ci=53, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_38_nu_43e-8.png
# Simulando para Ci=39, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_53_nu_45e-8.png
# Simulando para Ci=54, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_39_nu_43e-8.png
# Simulando para Ci=40, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_40_nu_43e-8.png
# Simulando para Ci=41, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_54_nu_45e-8.png
# Simulando para Ci=55, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_41_nu_43e-8.png
# Simulando para Ci=42, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_55_nu_45e-8.png
# Simulando para Ci=56, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_42_nu_43e-8.png
# Simulando para Ci=43, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_56_nu_45e-8.png
# Simulando para Ci=57, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_43_nu_43e-8.png
# Simulando para Ci=44, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_57_nu_45e-8.png
# Simulando para Ci=58, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_44_nu_43e-8.png
# Simulando para Ci=45, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_58_nu_45e-8.png
# Simulando para Ci=59, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_45_nu_43e-8.png
# Simulando para Ci=46, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_59_nu_45e-8.png
# Simulando para Ci=60, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_60_nu_45e-8.png
# Simulando para Ci=61, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_46_nu_43e-8.png
# Simulando para Ci=47, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_47_nu_43e-8.png
# Simulando para Ci=48, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_61_nu_45e-8.png
# Simulando para Ci=62, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_48_nu_43e-8.png
# Simulando para Ci=49, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_62_nu_45e-8.png
# Simulando para Ci=63, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_49_nu_43e-8.png
# Simulando para Ci=50, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_63_nu_45e-8.png
# Simulando para Ci=64, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_50_nu_43e-8.png
# Simulando para Ci=51, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_64_nu_45e-8.png
# Simulando para Ci=65, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_51_nu_43e-8.png
# Simulando para Ci=52, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_65_nu_45e-8.png
# Simulando para Ci=66, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_52_nu_43e-8.png
# Simulando para Ci=53, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_66_nu_45e-8.png
# Simulando para Ci=67, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_53_nu_43e-8.png
# Simulando para Ci=54, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_67_nu_45e-8.png
# Simulando para Ci=68, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_54_nu_43e-8.png
# Simulando para Ci=55, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_68_nu_45e-8.png
# Simulando para Ci=69, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_55_nu_43e-8.png
# Simulando para Ci=56, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_69_nu_45e-8.png
# Simulando para Ci=70, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_56_nu_43e-8.png
# Simulando para Ci=57, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_70_nu_45e-8.png
# Simulando para Ci=71, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_57_nu_43e-8.png
# Simulando para Ci=58, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_71_nu_45e-8.png
# Simulando para Ci=72, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_58_nu_43e-8.png
# Simulando para Ci=59, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_72_nu_45e-8.png
# Simulando para Ci=73, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_59_nu_43e-8.png
# Simulando para Ci=60, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_73_nu_45e-8.png
# Simulando para Ci=74, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_60_nu_43e-8.png
# Simulando para Ci=61, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_74_nu_45e-8.png
# Simulando para Ci=75, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_61_nu_43e-8.png
# Simulando para Ci=62, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_75_nu_45e-8.png
# Simulando para Ci=76, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_62_nu_43e-8.png
# Simulando para Ci=63, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_76_nu_45e-8.png
# Simulando para Ci=77, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_63_nu_43e-8.png
# Simulando para Ci=64, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_77_nu_45e-8.png
# Simulando para Ci=78, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_64_nu_43e-8.png
# Simulando para Ci=65, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_78_nu_45e-8.png
# Simulando para Ci=79, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_65_nu_43e-8.png
# Simulando para Ci=66, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_79_nu_45e-8.png
# Simulando para Ci=80, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_66_nu_43e-8.png
# Simulando para Ci=67, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_80_nu_45e-8.png
# Simulando para Ci=81, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_67_nu_43e-8.png
# Simulando para Ci=68, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_81_nu_45e-8.png
# Simulando para Ci=82, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_68_nu_43e-8.png
# Simulando para Ci=69, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_82_nu_45e-8.png
# Simulando para Ci=83, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_69_nu_43e-8.png
# Simulando para Ci=70, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_83_nu_45e-8.png
# Simulando para Ci=84, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_70_nu_43e-8.png
# Simulando para Ci=71, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_84_nu_45e-8.png
# Simulando para Ci=85, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_71_nu_43e-8.png
# Simulando para Ci=72, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_85_nu_45e-8.png
# Simulando para Ci=86, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_72_nu_43e-8.png
# Simulando para Ci=73, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_86_nu_45e-8.png
# Simulando para Ci=87, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_73_nu_43e-8.png
# Simulando para Ci=74, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_87_nu_45e-8.png
# Simulando para Ci=88, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_74_nu_43e-8.png
# Simulando para Ci=75, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_88_nu_45e-8.png
# Simulando para Ci=89, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_75_nu_43e-8.png
# Simulando para Ci=76, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_89_nu_45e-8.png
# Simulando para Ci=90, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_76_nu_43e-8.png
# Simulando para Ci=77, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_90_nu_45e-8.png
# Simulando para Ci=91, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_77_nu_43e-8.png
# Simulando para Ci=78, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_91_nu_45e-8.png
# Simulando para Ci=92, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_78_nu_43e-8.png
# Simulando para Ci=79, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_92_nu_45e-8.png
# Simulando para Ci=93, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_79_nu_43e-8.png
# Simulando para Ci=80, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_93_nu_45e-8.png
# Simulando para Ci=94, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_80_nu_43e-8.png
# Simulando para Ci=81, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_94_nu_45e-8.png
# Simulando para Ci=95, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_81_nu_43e-8.png
# Simulando para Ci=82, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_95_nu_45e-8.png
# Simulando para Ci=96, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_82_nu_43e-8.png
# Simulando para Ci=83, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_96_nu_45e-8.png
# Simulando para Ci=97, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_83_nu_43e-8.png
# Simulando para Ci=84, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_97_nu_45e-8.png
# Simulando para Ci=98, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_98_nu_45e-8.png
# Simulando para Ci=99, nu=45e-8...
# Número de Courant aproximado: 1.26e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_84_nu_43e-8.png
# Simulando para Ci=85, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_99_nu_45e-8.png
# Simulando para Ci=1, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_85_nu_43e-8.png
# Simulando para Ci=86, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_1_nu_46e-8.png
# Simulando para Ci=2, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_86_nu_43e-8.png
# Simulando para Ci=87, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_2_nu_46e-8.png
# Simulando para Ci=3, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_87_nu_43e-8.png
# Simulando para Ci=88, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_3_nu_46e-8.png
# Simulando para Ci=4, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_88_nu_43e-8.png
# Simulando para Ci=89, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_4_nu_46e-8.png
# Simulando para Ci=5, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_89_nu_43e-8.png
# Simulando para Ci=90, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_5_nu_46e-8.png
# Simulando para Ci=6, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_90_nu_43e-8.png
# Simulando para Ci=91, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_6_nu_46e-8.png
# Simulando para Ci=7, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_91_nu_43e-8.png
# Simulando para Ci=92, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_7_nu_46e-8.png
# Simulando para Ci=8, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_92_nu_43e-8.png
# Simulando para Ci=93, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_8_nu_46e-8.png
# Simulando para Ci=9, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_93_nu_43e-8.png
# Simulando para Ci=94, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_9_nu_46e-8.png
# Simulando para Ci=10, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_94_nu_43e-8.png
# Simulando para Ci=95, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_10_nu_46e-8.png
# Simulando para Ci=11, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_95_nu_43e-8.png
# Simulando para Ci=96, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_11_nu_46e-8.png
# Simulando para Ci=12, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_96_nu_43e-8.png
# Simulando para Ci=97, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_97_nu_43e-8.png
# Simulando para Ci=98, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_12_nu_46e-8.png
# Simulando para Ci=13, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_98_nu_43e-8.png
# Simulando para Ci=99, nu=43e-8...
# Número de Courant aproximado: 1.20e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_13_nu_46e-8.png
# Simulando para Ci=14, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_99_nu_43e-8.png
# Simulando para Ci=1, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_14_nu_46e-8.png
# Simulando para Ci=15, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_15_nu_46e-8.png
# Simulando para Ci=16, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_1_nu_44e-8.png
# Simulando para Ci=2, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_16_nu_46e-8.png
# Simulando para Ci=17, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_2_nu_44e-8.png
# Simulando para Ci=3, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_17_nu_46e-8.png
# Simulando para Ci=18, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_3_nu_44e-8.png
# Simulando para Ci=4, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_18_nu_46e-8.png
# Simulando para Ci=19, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_4_nu_44e-8.png
# Simulando para Ci=5, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_19_nu_46e-8.png
# Simulando para Ci=20, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_5_nu_44e-8.png
# Simulando para Ci=6, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_20_nu_46e-8.png
# Simulando para Ci=21, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_6_nu_44e-8.png
# Simulando para Ci=7, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_21_nu_46e-8.png
# Simulando para Ci=22, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_7_nu_44e-8.png
# Simulando para Ci=8, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_22_nu_46e-8.png
# Simulando para Ci=23, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_8_nu_44e-8.png
# Simulando para Ci=9, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_23_nu_46e-8.png
# Simulando para Ci=24, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_9_nu_44e-8.png
# Simulando para Ci=10, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_24_nu_46e-8.png
# Simulando para Ci=25, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_10_nu_44e-8.png
# Simulando para Ci=11, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_25_nu_46e-8.png
# Simulando para Ci=26, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_11_nu_44e-8.png
# Simulando para Ci=12, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_26_nu_46e-8.png
# Simulando para Ci=27, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_12_nu_44e-8.png
# Simulando para Ci=13, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_27_nu_46e-8.png
# Simulando para Ci=28, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_13_nu_44e-8.png
# Simulando para Ci=14, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_28_nu_46e-8.png
# Simulando para Ci=29, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_14_nu_44e-8.png
# Simulando para Ci=15, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_29_nu_46e-8.png
# Simulando para Ci=30, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_15_nu_44e-8.png
# Simulando para Ci=16, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_30_nu_46e-8.png
# Simulando para Ci=31, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_16_nu_44e-8.png
# Simulando para Ci=17, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_31_nu_46e-8.png
# Simulando para Ci=32, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_17_nu_44e-8.png
# Simulando para Ci=18, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_32_nu_46e-8.png
# Simulando para Ci=33, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_18_nu_44e-8.png
# Simulando para Ci=19, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_33_nu_46e-8.png
# Simulando para Ci=34, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_19_nu_44e-8.png
# Simulando para Ci=20, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_34_nu_46e-8.png
# Simulando para Ci=35, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_20_nu_44e-8.png
# Simulando para Ci=21, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_35_nu_46e-8.png
# Simulando para Ci=36, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_21_nu_44e-8.png
# Simulando para Ci=22, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_36_nu_46e-8.png
# Simulando para Ci=37, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_22_nu_44e-8.png
# Simulando para Ci=23, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_37_nu_46e-8.png
# Simulando para Ci=38, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_23_nu_44e-8.png
# Simulando para Ci=24, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_38_nu_46e-8.png
# Simulando para Ci=39, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_24_nu_44e-8.png
# Simulando para Ci=25, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_39_nu_46e-8.png
# Simulando para Ci=40, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_25_nu_44e-8.png
# Simulando para Ci=26, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_40_nu_46e-8.png
# Simulando para Ci=41, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_26_nu_44e-8.png
# Simulando para Ci=27, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_41_nu_46e-8.png
# Simulando para Ci=42, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_27_nu_44e-8.png
# Simulando para Ci=28, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_42_nu_46e-8.png
# Simulando para Ci=43, nu=46e-8...
# Número de Courant aproximado: 1.29e-01
# Guardado: /home/letmitaf/Escritorio/Difusion_images_4/Ci_28_nu_44e-8.png
# Simulando para Ci=29, nu=44e-8...
# Número de Courant aproximado: 1.23e-01
